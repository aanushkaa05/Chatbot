# %%
import re
import nltk
from nltk.stem import PorterStemmer

response = {'help':"What kind of help do you need?"} 

#The chatbot greets the user and asks its name
chat = input("Hi,This is Jasper: The fluffy genius!\n And you are?\n")
if not re.match(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat):
    name = re.findall("[a-zA-Z]+$", chat)
    print("Hi {}🖐🏼, what brings you here?🤔 \n".format(
      " ".join(name).replace(".", "")))
    
elif re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat):
        print("See ya later Alligator! Hope you have a good day!😄")
else:
    print("It was nice talking to you!")

#This block is rephrasing the text when user inputs 'help'    
chat0 = input()
if chat0 == 'help':
    list_item = response.get('help')
    print(list_item) 
else:
    pass

#This block is used for stripping the punctuation
chat1 = input()
if not re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat):
        name1 = re.sub(r'[^\w\s]','',chat1)
        print("I got busy eating my oreos😋\nDo you mean, {}?\n".format(
       "".join(name1).replace(".",""))) 
elif re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat1):
        print("See ya later Alligator! Hope you have a good day!😄")
else:
    print("It was nice talking to you!")

#This is the chatbot displaying the weather
chat2 = input()
if chat2 =="yes":
    print("The weather in Mt.Pleasant,MI is 46ºF🌞 and clear🌤.")
elif re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat2):
        print("See ya later Alligator! Hope you have a good day!😄")
else:
    print("It was nice talking to you!")
    
#This block is using to stem 'raining' to 'rain' using Porter Stemmer
chat3 = input()
if chat3 == 'raining':
        porter = PorterStemmer()
        name2 = chat3
        name2 = porter.stem("raining")
        print("The Sky is as clear as a Crsytal! There is no {} today!!\n".format(
       "".join(name2).replace(".",""))) 
elif re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat3):
        print("See ya later Alligator! Hope you have a good day!😄")
else:
    print("It was nice talking to you!")

#Extra input just for fun!
chat4 = input()
if chat4 =="sunglasses":
    print("The sun is as bright as your future! Gotta wear those shades😎!")
elif re.findall(r'([Bb]ye)$|([Ee]xit)$|([Qu]it)$', chat4):
        print("See ya later Alligator! Hope you have a good day!😄")
else:
    print("It was nice talking to you!")
